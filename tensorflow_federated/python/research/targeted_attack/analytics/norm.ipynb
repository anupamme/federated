# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
import json
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm
from sklearn.decomposition import PCA
import os
import imagesize

# %matplotlib inline

# %%
# pip install seaborn 
import seaborn as sns
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
data = pd.read_csv("norm_bound.csv")

print("{} data".format(data.shape[0]))
# Out:
# 24 data

# %%
data.head()
# Out:
#    norm_bound  rounds  test_metrics accuracy  test_metrics_target accuracy  \
# 0        0.15       0                 0.1690                        0.9480
# 1        0.15       5                 0.6660                        0.1204
# 2        0.15      10                 0.7961                        0.1355
# 3        0.15      15                 0.8549                        0.0572
# 4        0.15      20                 0.8802                        0.1380
#
#     loss1  loss2
# 0  2.2870  2.231
# 1  1.1950  2.315
# 2  0.6777  2.642
# 3  0.4560  2.788
# 4  0.3760  1.888

# %%
data.plot.scatter('norm_bound','test_metrics accuracy')

# %%
sns.barplot('norm_bound','test_metrics accuracy',data=data)

plt.show()

# %%
sns.barplot('norm_bound','test_metrics_target accuracy',data=data)

plt.show()

# %%
sns.barplot('norm_bound','loss1',data=data)

plt.show()

# %%
sns.barplot('norm_bound','loss2',data=data)

plt.show()
