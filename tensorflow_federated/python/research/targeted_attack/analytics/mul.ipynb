# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
import json
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm
from sklearn.decomposition import PCA
import os
import imagesize

# %matplotlib inline
# Out:
# C:\Users\Somil Jain\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# pip install seaborn 
import seaborn as sns
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
data = pd.read_csv("mul.csv")

print("{} data".format(data.shape[0]))
# Out:
# 18 data

# %%
data.head()
# Out:
#    mul_factor  rounds  test_metrics accuracy  test_metrics_target accuracy  \
# 0         0.0       0                 0.3220                        0.1566
# 1         0.0       5                 0.6740                        0.1470
# 2         0.0      10                 0.7400                        0.2650
# 3         0.0      15                 0.8311                        0.1144
# 4         0.0      20                 0.8490                        0.2710
#
#    loss1  loss2
# 0  2.280  2.270
# 1  1.316  1.974
# 2  0.777  1.854
# 3  0.530  2.316
# 4  0.452  1.370

# %%
data.plot.scatter('mul_factor','test_metrics accuracy')

# %%
sns.barplot('mul_factor','test_metrics accuracy',data=data)

plt.show()

# %%
sns.barplot('mul_factor','test_metrics_target accuracy',data=data)

plt.show()

# %%
sns.barplot('mul_factor','loss1',data=data)

plt.show()

# %%
sns.barplot('mul_factor','loss2',data=data)

plt.show()
